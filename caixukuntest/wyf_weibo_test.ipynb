# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
from pandas.io.json import json_normalize

# %%
conn = MongoClient(host='127.0.0.1', port=27017)  # 实例化MongoClient
db = conn.get_database('test1')  # 连接到CaiXuKun数据库

repost = db.get_collection('repost') # 连接到集合repost
mon_data = repost.find()  # 查询这个集合下的所有记录

# %%
data = json_normalize([comment for comment in mon_data])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 87 columns):
# _id                                 413 non-null object
# attitudes_count                     413 non-null int64
# bid                                 413 non-null object
# can_edit                            413 non-null bool
# cardid                              9 non-null object
# comments_count                      413 non-null int64
# content_auth                        413 non-null int64
# created_at                          413 non-null object
# darwin_tags                         413 non-null object
# favorited                           413 non-null bool
# hide_flag                           413 non-null int64
# id                                  413 non-null object
# isLongText                          413 non-null bool
# is_paid                             413 non-null bool
# mblog_vip_type                      413 non-null int64
# mblogtype                           413 non-null int64
# mid                                 413 non-null object
# more_info_type                      413 non-null int64
# pending_approval_count              413 non-null int64
# pic_ids                             413 non-null object
# pic_types                           413 non-null object
# pid                                 378 non-null float64
# pidstr                              378 non-null object
# raw_text                            413 non-null object
# reposts_count                       413 non-null int64
# reward_exhibition_type              413 non-null int64
# show_additional_indication          413 non-null int64
# source                              413 non-null object
# user.avatar_hd                      413 non-null object
# user.badge.anniversary              1 non-null float64
# user.badge.asiad_2018               1 non-null float64
# user.badge.bind_taobao              17 non-null float64
# user.badge.cz_wed_2017              3 non-null float64
# user.badge.dailv                    1 non-null float64
# user.badge.dailv_2018               23 non-null float64
# user.badge.denglong_2019            5 non-null float64
# user.badge.double11_2018            11 non-null float64
# user.badge.dzwbqlx_2016             17 non-null float64
# user.badge.earth_2019               1 non-null float64
# user.badge.fu_2019                  6 non-null float64
# user.badge.gongyi_level             3 non-null float64
# user.badge.hongbaofei_2019          35 non-null float64
# user.badge.lol_gm_2017              1 non-null float64
# user.badge.lol_msi_2017             1 non-null float64
# user.badge.memorial_2018            11 non-null float64
# user.badge.national_day_2018        15 non-null float64
# user.badge.panda                    22 non-null float64
# user.badge.qixi_2018                31 non-null float64
# user.badge.status_visible           9 non-null float64
# user.badge.suishoupai_2018          19 non-null float64
# user.badge.suishoupai_2019          33 non-null float64
# user.badge.super_star_2017          5 non-null float64
# user.badge.super_star_2018          11 non-null float64
# user.badge.travel_2017              8 non-null float64
# user.badge.unread_pool              32 non-null float64
# user.badge.unread_pool_ext          31 non-null float64
# user.badge.user_name_certificate    412 non-null float64
# user.badge.vip_activity2            4 non-null float64
# user.badge.wbzy_2018                29 non-null float64
# user.badge.wenchuan_10th            17 non-null float64
# user.badge.wenda_v2                 18 non-null float64
# user.badge.womensday_2018           3 non-null float64
# user.badge.worldcup_2018            9 non-null float64
# user.badge.wusi_2019                13 non-null float64
# user.badge.zongyiji                 8 non-null float64
# user.close_blue_v                   413 non-null bool
# user.cover_image_phone              413 non-null object
# user.description                    413 non-null object
# user.follow_count                   413 non-null int64
# user.follow_me                      413 non-null bool
# user.followers_count                413 non-null int64
# user.following                      413 non-null bool
# user.gender                         413 non-null object
# user.id                             413 non-null int64
# user.like                           413 non-null bool
# user.like_me                        413 non-null bool
# user.mbrank                         413 non-null int64
# user.mbtype                         413 non-null int64
# user.profile_image_url              413 non-null object
# user.profile_url                    413 non-null object
# user.screen_name                    413 non-null object
# user.statuses_count                 413 non-null int64
# user.urank                          413 non-null int64
# user.verified                       413 non-null bool
# user.verified_reason                4 non-null object
# user.verified_type                  413 non-null int64
# user.verified_type_ext              4 non-null float64
# dtypes: bool(10), float64(38), int64(19), object(20)
# memory usage: 252.6+ KB

# %%
data.sample(5)
# Out:
#                           _id  attitudes_count        bid  can_edit cardid  \
# 202  5cfe78514ee927be75e1ff40                1  Hy8oScrp6     False    NaN
# 28   5cfe784c4ee927be75e1fde3                0  Hvm12tXmB     False    NaN
# 197  5cfe78514ee927be75e1ff36                0  HvkAelvfW     False    NaN
# 293  5cfe78544ee927be75e1fff7                0  Hvkpmi3A9     False    NaN
# 86   5cfe784e4ee927be75e1fe57                0  HvlxUc4n1     False    NaN
#
#      comments_count  content_auth created_at darwin_tags  favorited  \
# 202               0             0   昨天 19:29          []      False
# 28                0             0      05-22          []      False
# 197               0             0      05-22          []      False
# 293               0             0      05-22          []      False
# 86                0             0      05-22          []      False
#
#              ...            user.mbtype  \
# 202          ...                      0
# 28           ...                      0
# 197          ...                      0
# 293          ...                      0
# 86           ...                      2
#
#                                 user.profile_image_url  \
# 202  https://tvax1.sinaimg.cn/crop.0.0.1447.1447.18...
# 28   https://tvax2.sinaimg.cn/crop.0.0.100.100.180/...
# 197  https://tvax2.sinaimg.cn/crop.0.0.100.100.180/...
# 293  https://tvax1.sinaimg.cn/crop.0.0.100.100.180/...
# 86   https://tvax2.sinaimg.cn/crop.0.0.996.996.180/...
#
#                                    user.profile_url  user.screen_name  \
# 202  https://m.weibo.cn/u/2022398897?uid=2022398897            Chen思伶
# 28   https://m.weibo.cn/u/6711563175?uid=6711563175         独妩二_hsxwx
# 197  https://m.weibo.cn/u/6859214857?uid=6859214857         注定不凡_iv0l
# 293  https://m.weibo.cn/u/6859998967?uid=6859998967      用户6859998967
# 86   https://m.weibo.cn/u/5748994878?uid=5748994878            肥墩的十一月
#
#      user.statuses_count  user.urank user.verified  user.verified_reason  \
# 202                  296          25         False                   NaN
# 28                   751           4         False                   NaN
# 197                  659           4         False                   NaN
# 293                  645           4         False                   NaN
# 86                  4482          27         False                   NaN
#
#      user.verified_type user.verified_type_ext
# 202                 220                    NaN
# 28                   -1                    NaN
# 197                  -1                    NaN
# 293                  -1                    NaN
# 86                   -1                    NaN
#
# [5 rows x 87 columns]

# %%
data.columns
# Out:
# Index(['_id', 'attitudes_count', 'bid', 'can_edit', 'cardid', 'comments_count',
#        'content_auth', 'created_at', 'darwin_tags', 'favorited', 'hide_flag',
#        'id', 'isLongText', 'is_paid', 'mblog_vip_type', 'mblogtype', 'mid',
#        'more_info_type', 'pending_approval_count', 'pic_ids', 'pic_types',
#        'pid', 'pidstr', 'raw_text', 'reposts_count', 'reward_exhibition_type',
#        'show_additional_indication', 'source', 'user.avatar_hd',
#        'user.badge.anniversary', 'user.badge.asiad_2018',
#        'user.badge.bind_taobao', 'user.badge.cz_wed_2017', 'user.badge.dailv',
#        'user.badge.dailv_2018', 'user.badge.denglong_2019',
#        'user.badge.double11_2018', 'user.badge.dzwbqlx_2016',
#        'user.badge.earth_2019', 'user.badge.fu_2019',
#        'user.badge.gongyi_level', 'user.badge.hongbaofei_2019',
#        'user.badge.lol_gm_2017', 'user.badge.lol_msi_2017',
#        'user.badge.memorial_2018', 'user.badge.national_day_2018',
#        'user.badge.panda', 'user.badge.qixi_2018', 'user.badge.status_visible',
#        'user.badge.suishoupai_2018', 'user.badge.suishoupai_2019',
#        'user.badge.super_star_2017', 'user.badge.super_star_2018',
#        'user.badge.travel_2017', 'user.badge.unread_pool',
#        'user.badge.unread_pool_ext', 'user.badge.user_name_certificate',
#        'user.badge.vip_activity2', 'user.badge.wbzy_2018',
#        'user.badge.wenchuan_10th', 'user.badge.wenda_v2',
#        'user.badge.womensday_2018', 'user.badge.worldcup_2018',
#        'user.badge.wusi_2019', 'user.badge.zongyiji', 'user.close_blue_v',
#        'user.cover_image_phone', 'user.description', 'user.follow_count',
#        'user.follow_me', 'user.followers_count', 'user.following',
#        'user.gender', 'user.id', 'user.like', 'user.like_me', 'user.mbrank',
#        'user.mbtype', 'user.profile_image_url', 'user.profile_url',
#        'user.screen_name', 'user.statuses_count', 'user.urank',
#        'user.verified', 'user.verified_reason', 'user.verified_type',
#        'user.verified_type_ext'],
#       dtype='object')

# %%
in_columns = ['attitudes_count', 'comments_count', 'reposts_count', 'mid', 'raw_text', 
          'source', 'user.description', 'user.follow_count', 'user.followers_count', 
          'user.gender', 'user.id', 'user.mbrank', 'user.mbtype', 'user.profile_url', 
          'user.profile_image_url', 'user.screen_name', 'user.statuses_count', 
          'user.urank', 'user.verified', 'user.verified_reason']

# %%
data = data[in_columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 20 columns):
# attitudes_count           413 non-null int64
# comments_count            413 non-null int64
# reposts_count             413 non-null int64
# mid                       413 non-null object
# raw_text                  413 non-null object
# source                    413 non-null object
# user.description          413 non-null object
# user.follow_count         413 non-null int64
# user.followers_count      413 non-null int64
# user.gender               413 non-null object
# user.id                   413 non-null int64
# user.mbrank               413 non-null int64
# user.mbtype               413 non-null int64
# user.profile_url          413 non-null object
# user.profile_image_url    413 non-null object
# user.screen_name          413 non-null object
# user.statuses_count       413 non-null int64
# user.urank                413 non-null int64
# user.verified             413 non-null bool
# user.verified_reason      4 non-null object
# dtypes: bool(1), int64(10), object(9)
# memory usage: 61.8+ KB

# %%
data.to_csv('caixukun.csv', index=False)

# %%
# 先来看看蔡徐坤的粉丝性别比例
fans_num = data['user.gender'].value_counts()
fans_num
# Out:
# m    312
# f    101
# Name: user.gender, dtype: int64

# %%
data[data['user.gender']=='m'].sample(5)
# Out:
#      attitudes_count  comments_count  reposts_count               mid  \
# 247                0               0              0  4374666296499406
# 197                0               0              0  4374672945125040
# 385                0               0              0  4374859091573553
# 300                0               0              0  4374666196290474
# 314                0               0              0  4374798278624712
#
#                                               raw_text         source  \
# 247  [嘻嘻]//@叶亦熙:快乐才是真谛#天·地·东·西·ALIVE TOUR吴亦凡2019巡回演...  Weico.Android
# 197  [鲜花]//@叶亦熙:快乐才是真谛#天·地·东·西·ALIVE TOUR吴亦凡2019巡回演...  Weico.Android
# 385  [doge]//@ALWAYS_十柒:快乐才是真谛//@吴亦凡Kris全球后援会:来吃面！#...        Android
# 300  [色]//@叶亦熙:快乐才是真谛#天·地·东·西·ALIVE TOUR吴亦凡2019巡回演唱...  Weico.Android
# 314  [哈欠]//@Moon_吴少女:#吴亦凡# 别去轻易否定自己，你拥有你的天地，没人能够把你定...        Android
#
#     user.description  user.follow_count  user.followers_count user.gender  \
# 247                                  61                     1           m
# 197                                  61                     1           m
# 385                                  60                     1           m
# 300                                  61                     1           m
# 314                                   0                     1           m
#
#         user.id  user.mbrank  user.mbtype  \
# 247  6859202510            0            0
# 197  6859214857            0            0
# 385  6854270625            0            0
# 300  6859253878            0            0
# 314  6970741386            0            0
#
#                                    user.profile_url  \
# 247  https://m.weibo.cn/u/6859202510?uid=6859202510
# 197  https://m.weibo.cn/u/6859214857?uid=6859214857
# 385  https://m.weibo.cn/u/6854270625?uid=6854270625
# 300  https://m.weibo.cn/u/6859253878?uid=6859253878
# 314  https://m.weibo.cn/u/6970741386?uid=6970741386
#
#                                 user.profile_image_url user.screen_name  \
# 247  https://tvax4.sinaimg.cn/crop.0.0.100.100.180/...         夏木学_rofl
# 197  https://tvax2.sinaimg.cn/crop.0.0.100.100.180/...        注定不凡_iv0l
# 385  https://tvax3.sinaimg.cn/crop.0.0.100.100.180/...         水深补_msd1
# 300  https://tvax4.sinaimg.cn/crop.0.0.100.100.180/...      wuli凡凡_ntty
# 314  https://tvax3.sinaimg.cn/default/images/defaul...     用户6970741386
#
#      user.statuses_count  user.urank  user.verified user.verified_reason
# 247                  669           4          False                  NaN
# 197                  659           4          False                  NaN
# 385                  426           0          False                  NaN
# 300                  678           4          False                  NaN
# 314                  136           4          False                  NaN

# %%
data_fake = data[((data['user.follow_count']<=5)|(data['user.followers_count']<=5))&
                 (data['user.description']=='')&
                 (data['comments_count']==0)&
                (data['attitudes_count']==0)&
                (data['reposts_count']==0)&
                (data['user.mbrank']==0)]
data_fake.sample(5)
# Out:
#      attitudes_count  comments_count  reposts_count               mid  \
# 106                0               0              0  4374728791919171
# 293                0               0              0  4374666204303677
# 96                 0               0              0  4374693454486137
# 242                0               0              0  4374666300365272
# 133                0               0              0  4374661753995798
#
#                                               raw_text         source  \
# 106  [二哈]//@Moon_吴少女:#吴亦凡# 别去轻易否定自己，你拥有你的天地，没人能够把你定...        Android
# 293  [鼓掌]//@叶亦熙:快乐才是真谛#天·地·东·西·ALIVE TOUR吴亦凡2019巡回演...  Weico.Android
# 96   [鲜花]//@叶亦熙:快乐才是真谛#天·地·东·西·ALIVE TOUR吴亦凡2019巡回演...  Weico.Android
# 242  [憧憬]//@叶亦熙:快乐才是真谛#天·地·东·西·ALIVE TOUR吴亦凡2019巡回演...  Weico.Android
# 133  [哈欠]//@叶亦熙:快乐才是真谛#天·地·东·西·ALIVE TOUR吴亦凡2019巡回演...  Weico.Android
#
#     user.description  user.follow_count  user.followers_count user.gender  \
# 106                                   0                     1           m
# 293                                  59                     1           f
# 96                                    0                     1           m
# 242                                  61                     3           m
# 133                                  60                     2           m
#
#         user.id  user.mbrank  user.mbtype  \
# 106  6906529220            0            0
# 293  6859998967            0            0
# 96   6972352634            0            0
# 242  6859945394            0            0
# 133  6859962580            0            0
#
#                                    user.profile_url  \
# 106  https://m.weibo.cn/u/6906529220?uid=6906529220
# 293  https://m.weibo.cn/u/6859998967?uid=6859998967
# 96   https://m.weibo.cn/u/6972352634?uid=6972352634
# 242  https://m.weibo.cn/u/6859945394?uid=6859945394
# 133  https://m.weibo.cn/u/6859962580?uid=6859962580
#
#                                 user.profile_image_url user.screen_name  \
# 106  https://tvax1.sinaimg.cn/default/images/defaul...     用户6906529220
# 293  https://tvax1.sinaimg.cn/crop.0.0.100.100.180/...     用户6859998967
# 96   https://tvax3.sinaimg.cn/default/images/defaul...     用户6972352634
# 242  https://tvax1.sinaimg.cn/crop.0.0.100.100.180/...        凡事有你_wugt
# 133  https://tvax3.sinaimg.cn/crop.0.0.100.100.180/...        命中有凡_fyxc
#
#      user.statuses_count  user.urank  user.verified user.verified_reason
# 106                  194           4          False                  NaN
# 293                  645           4          False                  NaN
# 96                   239           4          False                  NaN
# 242                  682           4          False                  NaN
# 133                  678           4          False                  NaN

# %%
data_fake.shape
# Out:
# (347, 20)

# %%
# 昵称里包含“用户”的，基本上可以断定是假粉丝
data_fake2_index = data[(data['user.follow_count']>5)&
                        (data['user.followers_count']>5)&
                        (data['user.screen_name'].str.contains('用户'))].index

# %%
# 把假的流量粉丝转发组合起来
data_fake = pd.concat([data_fake, data.iloc[data_fake2_index]])

# %%
data_fake.shape
# Out:
# (347, 20)

# %%
# 取出真粉的转发
data_true = data.drop(data_fake.index)

# %%
data_true.shape
# Out:
# (66, 20)

# %%
print('真粉丝转发数占总转发数的{}%'.format(np.round(data_true.shape[0]/data.shape[0]*100, 2)))
print('假粉丝转发数占总转发数的{}%'.format(np.round(data_fake.shape[0]/data.shape[0]*100, 2)))
# Out:
# 真粉丝转发数占总转发数的15.98%
# 假粉丝转发数占总转发数的84.02%
